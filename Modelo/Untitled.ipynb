# %%
import pandas as pd
import gme

# %%
df1 = pd.read_csv("Dados/Distanciamento/Distanciamento_Especificado.csv")
df2 = pd.read_csv("Dados/Exportações/Valor_Exportacao_Especificado.csv")
df3 = pd.read_csv("Dados/Tarifas/Tarifas_Especificadas.csv")
df4 = pd.read_csv("Dados/PIB Nominal/PIB_Nominal.csv")
    
df1.drop(columns={"Unnamed: 0"}, inplace=True)
    
df2.rename(columns={"Partner ISO": "Country Code"}, inplace=True)
df2.drop(columns={"Partner", "Commodity"}, inplace=True)
    
df3.drop(columns={ "Country Name"}, inplace=True)
df3.drop(columns={'Unnamed: 0'}, inplace = True)
df3.rename(columns={"Ano":"Year","Valores":"Tarifas"}, inplace=True)
    
df4.drop(columns={"Series Name", "Series Code", "Country Name"}, inplace=True)
df4 = df4.melt(id_vars="Country Code",
    var_name="Year",
    value_name="PIB_Nominal")
df4 = df4.dropna()
df4["Year"] = df4["Year"].apply(lambda x: str(x)[:-8])

df5 = pd.read_csv("Dados/Notificações/SPS_&_TBT.csv")

# %%
df = reduce(lambda  left,right: pd.merge(left,right,on=['DATE'],
                                            how='outer'), data_frames)

# %%
# Out:
#       Country Code  contig  comlang_off  comlang_ethno  colony  comcol  \
# 0              ABW       0            0              0       0       0
# 1              ABW       0            0              0       0       0
# 2              ABW       0            0              0       0       0
# 3              ABW       0            0              0       0       0
# 4              ABW       0            0              0       0       0
# ...            ...     ...          ...            ...     ...     ...
# 22880          ZWE       0            0              0       0       0
# 22881          ZWE       0            0              0       0       0
# 22882          ZWE       0            0              0       0       0
# 22883          ZWE       0            0              0       0       0
# 22884          ZWE       0            0              0       0       0
#
#        curcol  col45  smctry      dist   distcap     distw  distwces  Year  \
# ...

# %%
df
# Out:
# array(['..', '7.86', '6.67', ..., '24.94', '10.7', '13.71'], dtype=object)

# %%
df = df.loc[:,~df.columns.duplicated()]
df.set_index("Year", inplace=True)
df

# %%
df5 = pd.read_csv("Dados/Notificações/SPS_&_TBT.csv")
df5
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-10-f9c68b6d1851> in <module>
# ----> 1 df5 = pd.read_csv("Dados/Notificações/SPS_&_TBT.csv")
#       2 df5
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...
